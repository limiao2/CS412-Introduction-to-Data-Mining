# %%
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
from scipy.spatial import distance
from sklearn import preprocessing

# %%
df=pd.read_table('/Users/Li/Google Drive/UIUC_Study/2015Fall/CS412/HW/HW1/data/data.online.scores',names=['ID','Midterm','Final'])
df
# Out:
#       ID  Midterm  Final
# 0      0       97     95
# 1      1       83     99
# 2      2       79     81
# 3      3       72     84
# 4      4       92     84
# 5     27       61     68
# 6     28       93     93
# 7     29       98     90
# 8     45       59     81
# 9     46       71     89
# 10    47       92     93
# 11    48       79     99
# 12    49       94     90
# 13    50       61     78
# 14    51       76     94
# 15    52       94     87
# 16    53       83     90
# 17    54       39     82
# 18    55       80     93
# 19    56       53     71
# 20    57      100     98
# 21    58       78     91
# 22    59       97     96
# 23    60       69     93
# 24    61       55     93
# 25    62       90     83
# 26    63       75     90
# 27    64       58     82
# 28    65       93     99
# 29    66       81     98
# ..   ...      ...    ...
# 770  902       52     75
# 771  903       88     98
# 772  904       71     79
# 773  905       95     97
# 774  906       77     97
# 775  907       77     95
# 776  908       92     97
# 777  909       91     89
# 778  910       64     80
# 779  911       90    100
# 780  912       66     99
# 781  913       57     68
# 782  914       56     61
# 783  915       66     94
# 784  916       63     82
# 785  917       83     96
# 786  918       85     92
# 787  919       58     83
# 788  920       76     93
# 789  921       83     83
# 790  922       56     94
# 791  923       89     95
# 792  924       89     98
# 793  925       72     93
# 794  926       80     94
# 795  927       90     92
# 796  928       80     85
# 797  929       91     95
# 798  930       62     58
# 799  931       75    100
#
# [800 rows x 3 columns]

# %%
d = np.array(df['Midterm'])

# %%
np.mean(d)
# Out:
# 76.813749999999999

# %%
np.var(d,ddof=1)
# Out:
# 171.39580569461828

# %%
std_scale = preprocessing.StandardScaler().fit(d)
df_std = std_scale.transform(d)
# Out:
# /Users/Li/miniconda/envs/adsa/lib/python2.7/site-packages/sklearn/utils/validation.py:498: UserWarning: StandardScaler assumes floating point values as input, got int64
#   "got %s" % (estimator, X.dtype))

# %%
df_std.mean()
# Out:
# 9.3258734068513146e-17

# %%
df_std.var()
# Out:
# 1.0

# %%
(90-np.mean(d))/np.std(d)
# Out:
# 1.007842838656944
